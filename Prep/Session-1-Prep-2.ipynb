# %%
print("hello world!")
# Out:
# hello world!

# %%
import collections

collections.defaultdict()

list()

print()

set()

dict()

# %%
print(x)
# Out:
# 1

# %%
x = 1

# %%
y = 2.5

# %% [markdown]
# An _underscore_ or *Aestrik* makes it italic

# %% [markdown]
# making it two times __underscore__ or **Aestrik** makes it bold

# %% [markdown]
# # Title
# ## Heading
# ### Subheading
# #### smaller heading
# ##### even smaller heading

# %% [markdown]
# __"This one makes it bold."__
#
# **"This one as well"**
#
# _"A single underscore makes it italic"_
#
# *"And a single star on both sides as well"*
#
# ***"This will be both bold and italic"***

# %% [markdown]
# ` def print_hello():
#     print("hello world")
#     `

# %% [markdown]
# we can add linebreak,
# as it will not take sometimes <br>
# Like the above case,

# %% [markdown]
# Use `>` to indent your code
#
# This is first line
# >This is second line
# >>This is third line
# >>>This is fourth line

# %% [markdown]
# -  use a dash and two spaces for a bullet
#     -  and a tab, dash and two spaces for a sub bullet

# %% [markdown]
# 1.  Use numbers to use as points
# 2.  and so on to keep adding points
#     1. tab and number to automatically detect sub points

# %% [markdown]
# <font color = "blue"> This is blue</font>
# <font color = "red"> This is red</font>

# %% [markdown]
# You can add image from web using `<img src= "image path" >`
#
# Example:
#     <img src='https://www.upgrad.com/blog/wp-content/uploads/2019/03/upGrad.png'>

# %% [markdown]
# You can also write equations in Jupyter notebook using Latex.
#
# Use a signle `$` on either side to write a latex equation.
#
# Example:
#
# $(\frac{a_1}{a_2} + \frac{a_3}{a_4})^2  =  {a_5}^3$
#
#
# [link](https://en.wikibooks.org/wiki/LaTeX/Mathematics) for more about Latex syntax

# %%
#Variables



#Lists

#Sets

#Tuples

#Dictionaries

#Control Structures

#if-else blocks

#for loop / while loop

# %%
name = [1,2,3,4]
print(name)

name = input("Enter your name ")
print("Welcome " + name + " !")

x = 1
x

y = 2.5
y

name = "John"
name

is_present = False
is_absent = True
is_present, is_absent

x,y,name,is_present = (3,5.5,"Joseph",True)
x,y,name,is_present

type(x),type(y),type(name),type(is_present)

z = x + y
z

x = str(x)
y = int(y)
z = float(y)

print(type(x),x)
print(type(z),z)
# Out:
# [1, 2, 3, 4]

# %%
a = 6
b = 7

print("Addition : " , a+b)
print("Substraction : " , a-b)
print("Multiplication : " , a*b)
print("Division : " , a/b)
print("Floor Division : " , a//b)
print("Modulus : " , a%b)
print("Exponential : " , a**b)


print ((4*5) - 9 + 12 / 6)
# Out:
# Addition :  13
# Substraction :  -1
# Multiplication :  42
# Division :  0.8571428571428571
# Floor Division :  0
# Modulus :  6
# Exponential :  279936

# %%
help(str)

s = 'z'
t = 'mike'
u = "HELLO"

print(s,t,u)

s = "ABCDEFGH"
print(len(s))

print(s[4])

print(s[-1])

s[4] = 'Z'

s = "IJKLMNOP"
s

first_name = "Harry"
last_name = "Potter"
print(first_name + last_name)

print(first_name + " " + last_name)

age = 10
print('Hello, my name is ' + first_name + ' and I am ' + str(age))

dir(first_name)

name = 'Harry'
age = 20

# Arguments by position
print('My name is {name} and I am {age}'.format(name=name, age=age))

# F-Strings (3.6+)
print(f'Hello, my name is {name} and I am {age}')


s = 'helloworld'
print(s.capitalize())

print(s.swapcase())

a = "abcd"
print(a*4)

print(s.upper())

print(s.lower())

print(len(s))

print(s.count('l'))

print(s.startswith('hello'))

print(s.startswith('h'))

print(s.startswith('he'))

print(s.replace('world','everyone'))

print(s.endswith('one'))

print(s)

s.replace('world','everyone')
s

print(s.isalnum())

print (s.isalpha())

print(s.isnumeric())
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
t = ('Mumbai',84,'Python',True)
t

u = 'Bangalore',95,False
u

v = 1,
v

v = (1,)
type(v)

v = (1)
type(v)

t[3]

t[0:2]

t[-2:]

fruits = ('Apples', 'Oranges', 'Grapes')

vegetables = ('Tomatoes','Potatoes','Onions')

basket = fruits + vegetables
basket

fruits = ('Apples','Grapes','Oranges')

new_fruits = fruits[0:2] + ('Kiwi',) + fruits[2:] 
new_fruits

t = (1,2.5,5,3)
print("Sum " ,sum(t))
print("Min ", min(t))
print("Max", max(t))

sorted(t)

tuple(sorted(t))

t = (1,5,'Disco',('Python','Java'))
print(t[3][1])

print(5 in t)

print(t)

t = (1,2,3,4)
a,b,c,d = t

print(a,b,c,d)

print(dir(t))
del(t)
print(t)
# Out:
# Sum  11.5
# Min  1
# Max 5
# Java
# True
# (1, 5, 'Disco', ('Python', 'Java'))
# 1 2 3 4
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-147-1a7373d4393f> in <module>
#      55 print(dir(t))
#      56 del(t)
# ---> 57 print(t)
#
# NameError: name 't' is not defined

# %%
l = [1,2,3,4]
fruits = ['Oranges','Mangoes','Apples']

nested_list = [1,2,['Oranges,''Apples'],('Mumbai','Bangalore')]

print (l,fruits,nested_list)

print(len(l))
print(l[2])
print(l[-1])
print(l[0:2])
print(l[-3:])

fruits[2]='Papaya'
fruits

fruits.extend(['Mangoes','Guava','Kiwi','PineApples'])
fruits

fruits.append('Jackfruit')

fruits

fruits.insert(2,'Grapes')

fruits

fruits.pop()

fruits

fruits.remove('Mangoes')

fruits

del fruits[2]
fruits

'Oranges' in fruits

l = [11,13,5,7.8,9,10]

print(sorted(l))
print(l)
print(l.sort())
print(l)



A = ['Apple','Straberry','Mango']
B =A
A[0] = 'Oranges'
print(A)
print(B)

C = A[:]
A[1]= 'PineApple'
print(A)
print(C)
# Out:
# [1, 2, 3, 4] ['Oranges', 'Mangoes', 'Apples'] [1, 2, ['Oranges,Apples'], ('Mumbai', 'Bangalore')]

# %%
s = set()
s = set([1,2,3,1,2,5,6,7])
print(s)

len(s)

s.add(4)

s

s.remove(5)

del s

s

s = {1,2,3,4,5}
t = {1,2,3,4,6,7}

s | t

s & t

s - t
# Out:
# {1, 2, 3, 5, 6, 7}

# %%
print(type({}))
type(set({}))

curr = {"India" : "INR", "USA" :"USD" , "Europe": "Pound"}

print(curr)
print(len(curr))
print(curr["India"])

curr["Japan"] = "Yen"
print(curr)

print(curr.keys())
print(curr.values())
print(curr.items())
print(sorted(curr))


curr["India"] = "Rupee"
print(curr)

del curr["Japan"]
print(curr)

curr.update({"USA" :"Dollar"})
print(curr)

curr.pop("Europe")
print(curr)

new_curr = curr.copy()

print(new_curr)
curr["Europe"] = "GBP"
print(curr)
print(new_curr)

persons = [{"name" : "John", "age":15} ,{"name":"Joseph", "age":30}]
print(persons[1]["name"])
print(persons[1])
# Out:
# <class 'dict'>
# set

# %%
dir(dict)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
# If/ Else conditions are used to decide to do something based on something being true or false

x = 21
y = 20

# Comparison Operators (==, !=, >, <, >=, <=) - Used to compare values

# Simple if
if x > y:
  print(f'{x} is greater than {y}')
# Out:
# 21 is greater than 20

# %%
# If/else
if x > y:
  print(f'{x} is greater than {y}')
else:
  print(f'{y} is greater than {x}')  

# elif
if x > y:
  print(f'{x} is greater than {y}')
elif x == y:
  print(f'{x} is equal to {y}')  
else:
  print(f'{y} is greater than {x}')
# Out:
# 21 is greater than 20
# 21 is greater than 20

# %%
# Nested if
if x > 2:
  if x <= 10:
    print(f'{x} is greater than 2 and less than or equal to 10')
    

# Logical operators (and, or, not) - Used to combine conditional statements

# and
if x > 2 and x <= 10:
    print(f'{x} is greater than 2 and less than or equal to 10')

# or
if x > 2 or x <= 10:
    print(f'{x} is greater than 2 or less than or equal to 10')

# not
if not(x == y):
  print(f'{x} is not equal to {y}')


# Membership Operators (not, not in) - Membership operators are used to test if a sequence is presented in an object

numbers = [1,2,3,4,5]

#  in
if x in numbers:
  print(x in numbers)

# not in
if x not in numbers:
  print(x not in numbers)

# Identity Operators (is, is not) - Compare the objects, not if they are equal, but if they are actually the same object, with the same memory location:

# is
if x is y:
  print(x is y)

# is not
if x is not y:
  print(x is not y)
# Out:
# 21 is greater than 2 or less than or equal to 10
# 21 is not equal to 20
# True
# True

# %%
# A for loop is used for iterating over a sequence (that is either a list, a tuple, a dictionary, a set, or a string).

people = ['John', 'Paul', 'Sara', 'Susan']

# Simple for loop
for person in people:
  print(f'Current Person: {person}')

# Break
for person in people:
  if person == 'Sara':
    break
  print(f'Current Person: {person}')

# Continue
for person in people:
  if person == 'Sara':
    continue
  print(f'Current Person: {person}')

# range
for i in range(len(people)):
  print(people[i])

for i in range(0, 11):
  print(f'Number: {i}')

# While loops execute a set of statements as long as a condition is true.

count = 0
while count < 10:
  print(f'Count: {count}')
  count += 1
# Out:
# Current Person: John
# Current Person: Paul
# Current Person: Sara
# Current Person: Susan
# Current Person: John
# Current Person: Paul
# Current Person: John
# Current Person: Paul
# Current Person: Susan
# John
# Paul
# Sara
# Susan
# Number: 0
# Number: 1
# Number: 2
# Number: 3
# Number: 4
# Number: 5
# Number: 6
# Number: 7
# Number: 8
# Number: 9
# Number: 10
# Count: 0
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5
# Count: 6
# Count: 7
# Count: 8
# Count: 9

# %%
l = ["newyork","california","texas"]
p = ["city", "county", "boys"]


lens = [len(c) for c in l]
print(lens)

new_lens = [c + k for c,k in zip(l,p)]
print(new_lens)

dict_lens = {c:len(c) for c in l}
print(dict_lens)
# Out:
# [7, 10, 5]
# ['newyorkcity', 'californiacounty', 'texasboys']
# {'newyork': 7, 'california': 10, 'texas': 5}
